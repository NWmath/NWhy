# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import os.path

# %matplotlib inline
os.environ['PATH'] = os.environ['PATH'] + ':/Library/TeX/texbin/latex'
plt.rc('text', usetex=True)

# %% [markdown]
# Read degree distribution from a text file vertex by vertex.

# %%
# read degree dist file into an dict
def read_deg_dist(file):
    with open(file) as f:
        degree_sequence = {}
        deg = []
        cnt = []
        for line in f: # read rest of lines
            [k, v] = list(map(int, line.split()))
            deg.append(k)
            cnt.append(v)

    return deg, cnt

# %% [markdown]
# # Degree histogram
#
#
# Draw degree histogram with matplotlib.
# Random graph shown as inset

# %%
# plot hist for degree distribution
def draw_deg_dist_hist(deg, cnt, file, width = 0.80, 
                       xlog = True, ylog = True,
                      scilimits = (0, 0)):
    font_size = 40
    fig, ax = plt.subplots()
    plt.bar(deg, cnt, width=width, color="0.5", edgecolor='black')

    plt.title("Degree Histogram")
    plt.ticklabel_format(style='sci', axis='both', scilimits=scilimits)
    ax.set_ylabel("Count", fontsize = font_size)
    ax.set_xlabel('Degree', fontsize = font_size)
    ax.tick_params(labelsize = font_size)
    
    if xlog:
        ax.set_xscale('log')
    if ylog:
        ax.set_yscale('log')


    plt.show()
    fig.savefig(file + '.pdf', format = 'pdf', bbox_inches='tight')
    fig.savefig(file + '.eps', format = 'eps', bbox_inches='tight', dpi = fig.dpi)
    return

# %%
file = 'dns/dns-001.mtx0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, xlog=False)

# %%
file = 'dns/dns-004.mtx0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file)

# %%
file = 'dns/dns-008.mtx0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.001, xlog=False, ylog=True)

# %%
file2 = 'dns/dns-032.mtx0dd'
deg, cnt = read_deg_dist(file2)
draw_deg_dist_hist(deg, cnt, file2, width=0.001, xlog=False, ylog=True)

# %%
file2 = 'dns/dns-256.mtx0dd'
deg, cnt = read_deg_dist(file2)
draw_deg_dist_hist(deg, cnt, file2, width=0.001, xlog=False, ylog=True)

# %%
file='real-world/NotreDame_actors.mtx0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)

# %%
file='real-world/IMDB.mtx0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)

# %%
file='real-world/12month1.mtx0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)

# %%
file='real-world/connectus.mtx0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)

# %%
file='julian/friendster-hygra0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)

# %%
file='julian/com-orkut-hygra0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)

# %%
file='julian/livejournal-hygra0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)

# %%
file='julian/orkut-group-hygra0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)

# %%
file='julian/web-hygra0dd'
deg, cnt = read_deg_dist(file)
draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-154-40269f4c8514> in <module>
#       1 file='julian/web-hygra0dd'
#       2 deg, cnt = read_deg_dist(file)
# ----> 3 draw_deg_dist_hist(deg, cnt, file, width=0.0001, xlog=False, ylog=True)
#
# <ipython-input-153-4c5591944680> in draw_deg_dist_hist(deg, cnt, file, width, xlog, ylog, scilimits)
#       5     font_size = 40
#       6     fig, ax = plt.subplots()
# ----> 7     plt.bar(deg, cnt, width=width, color="0.5", edgecolor='black', scilimits=scilimits)
#       8
#       9     plt.title("Degree Histogram")
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2430         x, height, width=0.8, bottom=None, *, align='center',
#    2431         data=None, **kwargs):
# -> 2432     return gca().bar(
#    2433         x, height, width=width, bottom=bottom, align=align,
#    2434         **({"data": data} if data is not None else {}), **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2429                 label='_nolegend_',
#    2430                 )
# -> 2431             r.update(kwargs)
#    2432             r.get_path()._interpolation_steps = 100
#    2433             if orientation == 'vertical':
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     967                 func = getattr(self, 'set_' + k, None)
#     968                 if not callable(func):
# --> 969                     raise AttributeError('{!r} object has no property {!r}'
#     970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#
# AttributeError: 'Rectangle' object has no property 'scilimits'
