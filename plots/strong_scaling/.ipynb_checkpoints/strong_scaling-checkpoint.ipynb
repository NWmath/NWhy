# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import os.path

# %matplotlib inline
os.environ['PATH'] = os.environ['PATH'] + ':/Library/TeX/texbin/latex'
plt.rc('text', usetex=True)

# %%
def draw_scaling_lines(input_csvname, ax, ylim = []):
    df = pd.read_csv(input_csvname + '.csv', delimiter=',')
    
    from itertools import cycle
    linecycler = cycle(["-","--","-.",":"])
    markercycler = cycle(['o', 'v', 'D', 'd', 'p', 's'])
    
    from cycler import cycler
    monochrome = (cycler('color', ['k']) *
                  cycler('linestyle', ['-', '--', ':', '=.']) *
                  cycler('marker', ['^',',', '.']))
    styles = monochrome()
    lines = []
    for column in df.columns:
        if 'thread' == column: continue;
        lines.append(ax.plot(df[column], markersize=15, linewidth=5, **next(styles)))
        #, linestyle = next(linecycler), marker = next(markercycler), \
                             #markersize=15, linewidth=5))
    
    #ax.set_prop_cycle(monochrome)
    # associate each tick with thread number
    if [] != ylim:
        ax.set_ylim(ylim)
    #ax.set_xticklabels(df['threadnumber'])
    from matplotlib.ticker import FormatStrFormatter
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.f'))
    
    
    return df.columns, lines;

# %%
def draw_all_scaling_lines():
    #sns.set()
    #style must be one of white, dark, whitegrid, darkgrid, ticks
    #sns.set_style("whitegrid", {'grid.color': '.7', 'grid.linestyle': u'-', \
    #                            'axes.edgecolor': '.1', 'patch.force_edgecolor': True})
    #palette = sns.cubehelix_palette(n_colors=3, start=0, rot=0.3, gamma=2.1, \
    #                            hue=0.9, light=0.9, dark=0.5, reverse = False, as_cmap=False)
    # draw bar palette to show the color
    #sns.palplot(palette)
    #sns.set_palette(palette)
    
    font_size = 40
    fig = plt.figure(figsize = (20,8.5))
    fig.canvas.draw()
    
    
    xaxis_tick = [0, 1, 2, 3, 4, 5]
    xaxis_range = ['1', '2', '4', '8', '16', '32']
    #xaxis_tick = [1, 2, 4, 8, 16, 32]
    
    from matplotlib import ticker 
    ax1 = plt.subplot(111)
    
    ax1.set_title('dns64', fontsize = font_size)
    ax1.tick_params(labelsize = font_size)
    ax1.set_xticks(xaxis_tick)
    ax1.set_xscale('log', basex=2)
    ax1.set_ylabel('Runtime in second', fontsize = font_size)
    ax1.set_xlabel('Thread number', fontsize = font_size)
    ax1.set_xticklabels(xaxis_range, rotation=0) 
    ax1.get_yaxis().set_major_formatter(ticker.ScalarFormatter())
    columns1, lines1 = draw_scaling_lines('strong_scaling/strong_scaling_dns64', ax1, [0,1000])
  
    
    leg = fig.legend(ax1.lines, columns1[1:], ncol = 3, frameon=True, fancybox = True, \
                    prop={'size':font_size}, shadow = False, framealpha=0.1, bbox_to_anchor = (0.9, .78))
    #                 loc = 'upper center')
    leg.get_frame().set_edgecolor('k')
    leg.get_frame().set_linewidth(1)
    
    plt.tight_layout()
    plt.subplots_adjust(top = 0.8)
    plt.show()
    fig.savefig('strong_scaling_dns64.pdf', format = 'pdf', bbox_inches='tight')
    fig.savefig('strong_scaling_dns64.eps', format = 'eps', dpi = fig.dpi, bbox_inches='tight')
    return

draw_all_scaling_lines()

# %%
def draw_all_scaling_lines():
    sns.set()
    #style must be one of white, dark, whitegrid, darkgrid, ticks
    sns.set_style("whitegrid", {'grid.color': '.7', 'grid.linestyle': u'-', \
                                'axes.edgecolor': '.1', 'patch.force_edgecolor': True})
    palette = sns.cubehelix_palette(n_colors=3, start=0, rot=0.3, gamma=2.1, \
                                hue=0.9, light=0.9, dark=0.5, reverse = False, as_cmap=False)
    # draw bar palette to show the color
    #sns.palplot(palette)
    sns.set_palette(palette)
    
    font_size = 40
    fig = plt.figure(figsize = (20,8.5))
    fig.canvas.draw()
    
    
    xaxis_tick = [0, 1, 2, 3, 4, 5]
    xaxis_range = ['1', '2', '4', '8', '16', '32']
    
    
    from matplotlib import ticker 

    ax2 = plt.subplot(111)
    
    ax2.set_title('friendster', fontsize = font_size)
    ax2.tick_params(labelsize = font_size)
    ax2.set_xticks(xaxis_tick)
    ax2.set_ylabel('Runtime in second', fontsize = font_size)
    ax2.set_xlabel('Thread number', fontsize = font_size)
    ax2.set_xticklabels(xaxis_range, rotation=0) 
    ax2.get_yaxis().set_major_formatter(ticker.ScalarFormatter())
    columns2, lines2 = draw_scaling_lines('strong_scaling/strong_scaling_friendster', ax2, [0,40])
    
    
    leg = fig.legend(ax2.lines, columns2[1:], ncol = 3, frameon=True, fancybox = True, \
                    prop={'size':font_size}, shadow = False, framealpha=0.1, bbox_to_anchor = (0.9, .78))
    #                 loc = 'upper center')
    leg.get_frame().set_edgecolor('k')
    leg.get_frame().set_linewidth(1)
    
    plt.tight_layout()
    plt.subplots_adjust(top = 0.8)
    plt.show()
    fig.savefig('strong_scaling_friendster.pdf', format = 'pdf', bbox_inches='tight')
    fig.savefig('strong_scaling_friendster.eps', format = 'eps', dpi = fig.dpi, bbox_inches='tight')
    return

draw_all_scaling_lines()

# %%
def draw_all_scaling_lines():
    sns.set()
    #style must be one of white, dark, whitegrid, darkgrid, ticks
    sns.set_style("whitegrid", {'grid.color': '.7', 'grid.linestyle': u'-', \
                                'axes.edgecolor': '.1', 'patch.force_edgecolor': True})
    palette = sns.cubehelix_palette(n_colors=3, start=0, rot=0.3, gamma=2.1, \
                                hue=0.9, light=0.9, dark=0.5, reverse = False, as_cmap=False)
    # draw bar palette to show the color
    #sns.palplot(palette)
    sns.set_palette(palette)
    
    font_size = 40
    fig = plt.figure(figsize = (20,8.5))
    fig.canvas.draw()
    
    
    xaxis_tick = [0, 1, 2, 3, 4, 5]
    xaxis_range = ['1', '2', '4', '8', '16', '32']
    
    
    from matplotlib import ticker 
    ax1 = plt.subplot(111)
    
    ax1.set_title('imdb', fontsize = font_size)
    ax1.tick_params(labelsize = font_size)
    ax1.set_xticks(xaxis_tick)
    ax1.set_ylabel('Runtime in second', fontsize = font_size)
    ax1.set_xlabel('Number of Thread', fontsize = font_size)
    ax1.set_xticklabels(xaxis_range, rotation=0) 
    ax1.get_yaxis().set_major_formatter(ticker.ScalarFormatter())
    columns1, lines1 = draw_scaling_lines('strong_scaling/strong_scaling_imdb', ax1, [0,20])
    
    
    leg = fig.legend(ax1.lines, columns1[1:], ncol = 3, frameon=True, fancybox = True, \
                    prop={'size':font_size}, shadow = False, framealpha=0.1, bbox_to_anchor = (0.9, .78))
    #                 loc = 'upper center')
    leg.get_frame().set_edgecolor('k')
    leg.get_frame().set_linewidth(1)
    
    plt.tight_layout()
    plt.subplots_adjust(top = 0.8)
    plt.show()
    fig.savefig('strong_scaling_imdb.pdf', format = 'pdf', bbox_inches='tight')
    fig.savefig('strong_scaling_imdb.eps', format = 'eps', dpi = fig.dpi, bbox_inches='tight')
    return

draw_all_scaling_lines()

# %%
def draw_all_scaling_lines():
    sns.set()
    #style must be one of white, dark, whitegrid, darkgrid, ticks
    sns.set_style("whitegrid", {'grid.color': '.7', 'grid.linestyle': u'-', \
                                'axes.edgecolor': '.1', 'patch.force_edgecolor': True})
    palette = sns.cubehelix_palette(n_colors=3, start=0, rot=0.3, gamma=2.1, \
                                hue=0.9, light=0.9, dark=0.5, reverse = False, as_cmap=False)
    # draw bar palette to show the color
    #sns.palplot(palette)
    sns.set_palette(palette)
    
    font_size = 40
    fig = plt.figure(figsize = (20,8.5))
    fig.canvas.draw()
    
    
    xaxis_tick = [0, 1, 2, 3]
    xaxis_range = ['4', '8', '16', '32']
    
    
    from matplotlib import ticker 
    ax1 = plt.subplot(111)
    
    ax1.set_title('dns128', fontsize = font_size)
    ax1.tick_params(labelsize = font_size)
    ax1.set_xticks(xaxis_tick)
    ax1.set_ylabel('Runtime in second', fontsize = font_size)
    ax1.set_xlabel('Thread number', fontsize = font_size)
    ax1.set_xticklabels(xaxis_range, rotation=0) 
    ax1.get_yaxis().set_major_formatter(ticker.ScalarFormatter())
    columns1, lines1 = draw_scaling_lines('strong_scaling/strong_scaling_dns128', ax1, [0,1000])
  
    
    leg = fig.legend(ax1.lines, columns1[1:], ncol = 3, frameon=True, fancybox = True, \
                    prop={'size':font_size}, shadow = False, framealpha=0.1, bbox_to_anchor = (0.9, .78))
    #                 loc = 'upper center')
    leg.get_frame().set_edgecolor('k')
    leg.get_frame().set_linewidth(1)
    
    plt.tight_layout()
    plt.subplots_adjust(top = 0.8)
    plt.show()
    fig.savefig('strong_scaling_dns128.pdf', format = 'pdf', bbox_inches='tight')
    fig.savefig('strong_scaling_dns128.eps', format = 'eps', dpi = fig.dpi, bbox_inches='tight')
    return

draw_all_scaling_lines()
